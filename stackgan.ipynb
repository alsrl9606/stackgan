# %%
#텐서플로 2.4.1버전 삭제
# !pip uninstall tensorflow
# Out:
# Uninstalling tensorflow-2.4.1:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/import_pb_to_tensorboard
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.6/dist-packages/tensorflow-2.4.1.dist-info/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/*
# Proceed (y/n)? y
#   Successfully uninstalled tensorflow-2.4.1

# %%
#텐서플로 버전 0.12.1 설치
# !pip install tensorflow==0.12.1
# Out:
# ...
#      |████████████████████████████████| 43.1MB 109kB/s
# ...

# %%
#텐서플로 버전확인
import tensorflow as tf
tf.__version__

# %%
# g드라이브와 코랩 연동
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#필요 파일 g드라이브에 다운로드
# !git clone https://github.com/hanzhanggit/StackGAN.git '/gdrive/My Drive/StackGan'
# !wget https://www.robots.ox.ac.uk/~vgg/data/flowers/102/102flowers.tgz
# !wget https://www.robots.ox.ac.uk/~vgg/data/flowers/102/102segmentations.tgz
# !tar -zxvf 102flowers.tgz 
# !tar -zxvf 102segmentations.tgz 
# !tar -zxvf CUB_200_2011.tgz
# !tar -zxvf segmentations.tgz
# !gdown --id 0B3y_msrWZaXLaUc0UXpmcnhaVmM --output flowers.zip 
# !unzip flowers.zip

# %%
# !pip install gdown
# !pip install -U prettytensor
# !pip install prettytensor==0.7.1
# !pip install torchfile
# !pip install prettytensor
# !pip install -U scipy==1.2.0
# !python -m "misc.utils"

# %%
! echo $PYTHONPATH

import os
os.environ['PYTHONPATH'] += ":/content/gdrive/MyDrive/StackGan"

! echo $PYTHONPATH
# Out:
# /env/python:/content/gdrive/MyDrive/StackGan:/content/gdrive/MyDrive/StackGan:/content/gdrive/MyDrive/StackGan
# /env/python:/content/gdrive/MyDrive/StackGan:/content/gdrive/MyDrive/StackGan:/content/gdrive/MyDrive/StackGan:/content/gdrive/MyDrive/StackGan

# %%
cd /content/gdrive/My Drive/StackGan
# Out:
# /content/gdrive/My Drive/StackGan

# %%
# !sh demo/flowers_demo.sh
# Out:
# demo/flowers_demo.sh: 10: demo/flowers_demo.sh: th: not found
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:463: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:464: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:465: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...
