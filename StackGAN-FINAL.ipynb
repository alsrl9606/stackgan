# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://github.com/hanzhanggit/StackGAN-Pytorch
# Out:
# fatal: destination path 'StackGAN-Pytorch' already exists and is not an empty directory.

# %%
# !pip install http://download.pytorch.org/whl/cu80/torch-0.3.0.post4-cp36-cp36m-linux_x86_64.whl
# !pip install torchvision
# Out:
# ERROR: torch-0.3.0.post4-cp36-cp36m-linux_x86_64.whl is not a supported wheel on this platform.
# ...

# %%
 # !pip install tensorboard python-dateutil easydict pandas torchfile tensorboardX
# Out:
# ...
#      |████████████████████████████████| 317kB 19.1MB/s
# ...
#   Created wheel for torchfile: filename=torchfile-0.1.0-cp37-none-any.whl size=5713 sha256=f3d09bf7feda99b15df0d148baeb06bfc3503574467f456b9cee60d1c52bb55f
#   Stored in directory: /root/.cache/pip/wheels/b1/c3/d6/9a1cc8f3a99a0fc1124cae20153f36af59a6e683daca0a0814
# Successfully built torchfile
# ...

# %%
cd /content/drive/MyDrive/StackGAN-Pytorch/data/
# Out:
# /content/drive/MyDrive/StackGAN-Pytorch/data

# %%
# !gdown --id 0B3y_msrWZaXLQXVzOENCY2E3TlU
# !gdown --id 0B3y_msrWZaXLeEs5MTg0RC1fa0U
# !unzip coco.zip
# !unzip coco_test.zip -d coco/
#rm coco.zip coco_test.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=0B3y_msrWZaXLQXVzOENCY2E3TlU
# To: /content/drive/My Drive/StackGAN-Pytorch/data/coco.zip
# 1.59GB [00:10, 156MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=0B3y_msrWZaXLeEs5MTg0RC1fa0U
# To: /content/drive/My Drive/StackGAN-Pytorch/data/coco_test.zip
# 157MB [00:01, 110MB/s]
# Archive:  coco.zip
#    creating: coco/
#   inflating: coco/.DS_Store
#    creating: __MACOSX/
#    creating: __MACOSX/coco/
#   inflating: __MACOSX/coco/._.DS_Store
#    creating: coco/test/
#   inflating: coco/test/filename.txt
#   inflating: coco/test/filenames.pickle
#    creating: coco/train/
#   inflating: coco/train/char-CNN-RNN-embeddings.pickle
#   inflating: coco/train/filenames.pickle
# Archive:  coco_test.zip
#   inflating: coco/test/.DS_Store
#    creating: coco/__MACOSX/
#    creating: coco/__MACOSX/test/
#   inflating: coco/__MACOSX/test/._.DS_Store
#   inflating: coco/test/val_captions.t7
# ...

# %%
# !wget http://images.cocodataset.org/zips/train2014.zip
# !wget http://images.cocodataset.org/zips/val2014.zip
# !wget http://images.cocodataset.org/zips/test2014.zip
# !wget http://images.cocodataset.org/annotations/annotations_trainval2014.zip
# !wget http://images.cocodataset.org/annotations/image_info_test2014.zip
# Out:
# --2021-03-05 10:59:17--  http://images.cocodataset.org/zips/train2014.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.216.134.251
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.216.134.251|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13510573713 (13G) [application/zip]
# Saving to: ‘train2014.zip’
#
# train2014.zip       100%[===================>]  12.58G  74.1MB/s    in 5m 12s
#
# 2021-03-05 11:04:34 (41.3 MB/s) - ‘train2014.zip’ saved [13510573713/13510573713]
#
# --2021-03-05 11:04:34--  http://images.cocodataset.org/zips/val2014.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.216.28.52
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.216.28.52|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6645013297 (6.2G) [application/zip]
# Saving to: ‘val2014.zip’
#
# val2014.zip          12%[=>                  ] 766.23M  7.89MB/s    eta 11m 18s^C
# ...

# %%
cd models/coco
# Out:
# /content/StackGAN-Pytorch/models/coco

# %%
# !gdown --id 0B3y_msrWZaXLYjNra2ZSSmtVQlE
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=0B3y_msrWZaXLYjNra2ZSSmtVQlE
# To: /content/StackGAN-Pytorch/models/coco/coco_netG_epoch_90.pth
# 229MB [00:02, 100MB/s]

# %%
cd data/
# Out:
# /content/StackGAN-Pytorch/data

# %%
# !mv /content/StackGAN-Pytorch /content/drive/MyDrive/
# Out:
# ^C

# %%
 # !python main.py --cfg cfg/coco_eval.yml --gpu 0
# Out:
# Using config:
# {'CONFIG_NAME': 'stageII',
#  'CUDA': True,
#  'DATASET_NAME': 'coco',
#  'DATA_DIR': '../data/coco',
#  'EMBEDDING_TYPE': 'cnn-rnn',
#  'GAN': {'CONDITION_DIM': 128, 'DF_DIM': 96, 'GF_DIM': 192, 'R_NUM': 2},
#  'GPU_ID': '0',
#  'IMSIZE': 256,
#  'NET_D': '',
#  'NET_G': '../models/coco/netG_epoch_90.pth',
#  'STAGE': 2,
#  'STAGE1_G': '',
#  'TEXT': {'DIMENSION': 1024},
#  'TRAIN': {'BATCH_SIZE': 40,
#            'COEFF': {'KL': 2.0},
#            'DISCRIMINATOR_LR': 0.0002,
#            'FLAG': False,
#            'GENERATOR_LR': 0.0002,
#            'LR_DECAY_EPOCH': 600,
#            'MAX_EPOCH': 600,
#            'PRETRAINED_EPOCH': 600,
#            'PRETRAINED_MODEL': '',
#            'SNAPSHOT_INTERVAL': 50},
#  'VIS_COUNT': 64,
#  'WORKERS': 4,
#  'Z_DIM': 100}
# STAGE2_G(
#   (STAGE1_G): STAGE1_G(
#     (ca_net): CA_NET(
#       (fc): Linear(in_features=1024, out_features=256, bias=True)
#       (relu): ReLU()
#     )
#     (fc): Sequential(
# ...
